# %%
from ancombc_viz.simple_name import extract_p_g_or_f
from ancombc_viz.plotting import plot_group_bar

top30_short_names = {
    col: extract_p_g_or_f(col)
    for col in otu_top30.columns
}

ax = plot_group_bar(
    anc_control,
    covariate_value="Group[T.mmilow]",
    top_n=30,
    fc_cut=0.0,
    top_name_map=top30_short_names,
)
